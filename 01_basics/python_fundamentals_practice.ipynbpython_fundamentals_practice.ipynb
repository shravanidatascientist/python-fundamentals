# %% [markdown]
# # Basic python code

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %% [markdown]
# ###

# %%
3
# Out:
# 3

# %%
4
# Out:
# 4

# %%
5
# Out:
# 5

# %%
' My name is shravani '   ## with single quote
# Out:
# ' My name is shravani '

# %%
" my name is shravani"   ## with double quote
# Out:
# ' my name is shravani'

# %%
''' my name is shravani'''   ## with triple quotes

# %% [markdown]
# ## Arithemetic operator

# %% [markdown]
# - +, -, *, / //

# %%
10+5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10/5       ## decimal division
# Out:
# 2.0

# %%
10//5      ## int decimal division
# Out:
# 2

# %% [markdown]
# ### when to use print funtions

# %%
10 +5
10-5 
10*3                 # If we need multiple outputs then print is needed, if it is a single line code then print is not required
# Out:
# 30

# %% [markdown]
# ##### Let's check with print function

# %%
print (10 +5)
print (10-5 )
print (10*3)
# Out:
# 15
# 5
# 30

# %%
print (10/5)
print(10//2)
print ( 3*5)
print( 3**2)
# Out:
# 2.0
# 5
# 15
# 9

# %%
print(10+2*(3-5)) 
print(15-20*(4-2))
# Out:
# 6
# -25

# %%
_
# Out:
# '{"dataframes": [], "user": "Shravani"}'

# %%
_
# Out:
# '{"dataframes": [], "user": "Shravani"}'

# %% [markdown]
# # python variable

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
a = 5
a
# Out:
# 5

# %%
5 = a
5
# Out:
#   Cell In[5], line 1
#     5 = a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # syntax = variable/ object/identifier = value

# %% [markdown]
# ### Rules and regulations to define python variable

# %% [markdown]
# #### Rule 1- python variable doesn’t start with digit / number , but it can end with number

# %%
0 = a
# Out:
#   Cell In[2], line 1
#     0 = a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
2 = x
# Out:
#   Cell In[3], line 1
#     2 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a2 = 20 
a2
# Out:
# 20

# %% [markdown]
# #### Rule 2 - variable is case sensitive

# %%
shravani = 20
SHRAVANI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 shravani = 20
# ----> 2 SHRAVANI
#
# NameError: name 'SHRAVANI' is not defined

# %% [markdown]
# #### Rule 3 - special characters are not allowed

# %%
shravani@
# Out:
#   Cell In[10], line 1
#     shravani@
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Rule 4 - In variable only underscore is allowed

# %%
Shravani_ = "Data scientist"
Shravani_
# Out:
# 'Data scientist'

# %%
shravani_@ = 25
shravani_@             # bcz no speacial characters are allowed
# Out:
#   Cell In[10], line 1
#     shravani_@ = 25
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Rule 5 - keyword or reserves word are not define as variable

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# ## Python data types

# %% [markdown]
# #### Integer variable

# %%
age = 22
age       # here age is an variable it stores an integer value 22
# Out:
# 22

# %%
type(age)
# Out:
# int

# %%
weight = 50
weight
# Out:
# 50

# %% [markdown]
# ### Float variable

# %%
price = 30.5
price                  # Here price is a variable storing floating point number of 30.5
# Out:
# 30.5

# %%
type(price)
# Out:
# float

# %%
salary = 40000.0
salary
# Out:
# 40000.0

# %% [markdown]
# ### String variable

# %%
name =' shravani'
name                  # Here name is a varaible storing a string 'shravani'
# Out:
# ' shravani'

# %%
type(name)
# Out:
# str

# %%
chinnu = ' Welcome to the party'
chinnu
# Out:
# ' Welcome to the party'

# %% [markdown]
# ### Boolean variable

# %%
shrvani_is_active = True
shrvani_is_active          # Here shrvani_is_active is a variable storing a boolean value
# Out:
# True

# %%
type(shrvani_is_active)
# Out:
# bool

# %%
shrvani_is_inactive = False 
shrvani_is_inactive
# Out:
# False

# %% [markdown]
# ### Complex Variable

# %%
a = 10+ 5j
a                        # Here a is a varaible storing an complex number 

# Here (10 = RealPart , 5 = imaginary part , j = square root of -1)
#complex numbers are used to build some math applications
# Out:
# (10+5j)

# %%
b = 20 + 25j
b
# Out:
# (20+25j)

# %%
b.real
# Out:
# 20.0

# %%
b.imag
# Out:
# 25.0

# %%
a= 10+5j
b = 20+25j
print (a)
print(b)
# Out:
# (10+5j)
# (20+25j)

# %%
print (a+b)
# Out:
# (30+30j)

# %%
d= 20+ 5s
d             ### Here in complex number only j letter is allowed, other alphabets are not allowed, that's why we got an error as we use 's'
# Out:
#   Cell In[58], line 1
#     d= 20+ 5s
#            ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ##### Note every value has ids, if values changes id's also changes

# %% [markdown]
# ####### Let's check id's (address)

# %%
a = 10
id(a)
# Out:
# 140708314064072

# %%
b = 10
id(b)
# Out:
# 140708314064072

# %%
c = 20
id(c)                        # here the above both values got sa,e adress, as value changed id also changed
# Out:
# 140708314064392

# %% [markdown]
# ### Function with arugument / Function without argument

# %% [markdown]
# ## Lets check function iwth argument

# %%
asian_cars = ( 'toyota', 'bmw')
asian_cars                           # Here is function has 2 arguments/ paramters
# Out:
# ('toyota', 'bmw')

# %% [markdown]
# ### Function without argument

# %%
German_cars = ()
German_cars
# Out:
# ()

# %% [markdown]
# # String Indexing
# # Two Types Of Indexing ---- 1) Forward Indexing       2) Backward Indexing

# %%
name = ' shravani'
name                   # defined using single quotes
# Out:
# ' shravani'

# %%
type(name)
# Out:
# str

# %%
name = " shravani"
name                  # defined using double quotes
# Out:
# ' shravani'

# %%
name = ''' my
name
is
shravani'''

name                 # deifined using Triple quotes
# Out:
# ' my\nname\nis\nshravani'

# %% [markdown]
# ## Forward Indexing

# %% [markdown]
# #### It always starts from left to right , starts from zero

# %%
s = ' shravani ' 
s
# Out:
# ' shravani '

# %%
s[1]
# Out:
# 's'

# %%
s[5]
# Out:
# 'v'

# %%
s[8]
# Out:
# 'i'

# %% [markdown]
# # Backward Indexing

# %% [markdown]
# #### It always starts from right to left , starts from -1

# %%
s
# Out:
# ' shravani '

# %%
s[-1]
# Out:
# ' '

# %%
s[-5]
# Out:
# 'v'

# %%
s[-8]
# Out:
# 'h'

# %%
s[-10]
# Out:
# ' '

# %%
s[-12]      ## as the string consit of 12 range, not give the output
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 s[-12]
#
# IndexError: string index out of range

# %% [markdown]
# #  String Slicing

# %%
s = 'welcome to the party'
s
# Out:
# 'welcome to the party'

# %%
len(s)
# Out:
# 20

# %%
s[3]
# Out:
# 'c'

# %%
s[0]
# Out:
# 'w'

# %%
s[2:3]
# Out:
# 'l'

# %%
s[ 5:10]
# Out:
# 'me to'

# %%
s[6:20]
# Out:
# 'e to the party'

# %%
s[18:]                  ### print all elements from 18 t0 till last
# Out:
# 'ty'

# %%
s[:5]                   ### print the value from start index to n-1 which is 5-1 = 4
# Out:
# 'welco'

# %% [markdown]
# # Step Slicing

# %%
s
# Out:
# 'welcome to the party'

# %%
s[0:5:4]
# Out:
# 'wo'

# %%
s2 = 'shravani'
s2
# Out:
# 'shravani'

# %%
len(s2)
# Out:
# 8

# %%
s2[0:5:2]
# Out:
# 'srv'

# %%
s2[0:5:3]
# Out:
# 'sa'

# %%
s2[5:3:2]
# Out:
# ''

# %% [markdown]
# ### Backward step slicing

# %%
s3 = 'shaanu'
s3
# Out:
# 'shaanu'

# %%
len(s3)
# Out:
# 6

# %%
s3[-5]
# Out:
# 'h'

# %%
s3[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 s3[-8]
#
# IndexError: string index out of range

# %%
s3[-2]
# Out:
# 'n'

# %%
s3 [-2: -5]
# Out:
# ''

# %%
s3[-5:-1]
# Out:
# 'haan'

# %% [markdown]
# # Advance slicing

# %%
s4 = 'Datascience'
s4
# Out:
# 'Datascience'

# %%
len(s4)
# Out:
# 11

# %%
s4[:: 3]
# Out:
# 'Daic'

# %%
s4[::2]
# Out:
# 'Dtsine'

# %%
s4[::5]
# Out:
# 'Dce'

# %% [markdown]
# ## Backward advance slicing

# %%
s4
# Out:
# 'Datascience'

# %%
s4[::-1]
# Out:
# 'ecneicsataD'

# %%
s4[:: -2]
# Out:
# 'enistD'

# %%
s4[::-3]
# Out:
# 'eesa'

# %% [markdown]
# # Type casting

# %% [markdown]
# - Type casting means converting one data type to other data  type

# %% [markdown]
# ## Let's check typecasting from other data type to integer

# %%
int(5.4)    # boolean to int
# Out:
# 5

# %%
int('10')  # from number string to int
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
int(False)    # from boolean to int
# Out:
# 0

# %%
int (10+5j)   ## we cannot type cast from a complex to integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 int (10+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int (' shravani')   ## we  cam conver number string to int but we can't type caste tect string  to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 int (' shravani')
#
# ValueError: invalid literal for int() with base 10: ' shravani'

# %%
int(2.3, 5.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 int(2.3, 5.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# - Float, bool, number string can convert in to int
# - Complex and text string is not possible to type cast
# - we can not pass 2 arguments max only one 1 argument

# %% [markdown]
# # Let's check typecasting from other data type to float

# %%
float(10)
# Out:
# 10.0

# %%
float(True)
# Out:
# 1.0

# %%
float( False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float( ' shravani ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 float( ' shravani ')
#
# ValueError: could not convert string to float: ' shravani '

# %%
float ( 10+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 float ( 10+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# - From all other data type to float except text string and complex data type we can not type catse rest all other data type we can type caste

# %% [markdown]
# # Let's check typecasting from other data type to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex (True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(" shravani")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 complex(" shravani")
#
# ValueError: complex() arg is a malformed string

# %%
complex (10.5)
# Out:
# (10.5+0j)

# %%
complex (10.5, 20.5)
# Out:
# (10.5+20.5j)

# %%
complex ( True + False)
# Out:
# (1+0j)

# %%
complex ( False+ False)
# Out:
# 0j

# %%
complex( '10', ' 25')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 complex( '10', ' 25')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# - From all other data type to Complex
# ( Except Text string & two strings together or arg not possible to type caste

# %% [markdown]
# # Let's check typecasting from other data type to Boolean

# %%
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(' shravani ')
# Out:
# True

# %%
bool( 10.5)
# Out:
# True

# %%
bool (10+5j)
# Out:
# True

# %%
bool (2.3, 5.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 bool (2.3, 5.5)
#
# TypeError: bool expected at most 1 argument, got 2

# %% [markdown]
# - From all other data type to boolean is possible only non zero argument 1 & 0 is false
